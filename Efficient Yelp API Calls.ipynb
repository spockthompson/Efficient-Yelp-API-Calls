# %% [markdown]
# #Efficient Yelp API Calls
# - Scotty Thomason

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %%
# Load API Credentials
with open('/Users/scyjt/.secret/yelp_api.json') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['api-key'], timeout_s=5.0)

# %%
# set our API call parameters and filename before the first call
location = 'Saint Louis, MO 63101'
term = 'pizza'

# %%
JSON_FILE = "Data/results_in_progress_STL_pizza.json"
JSON_FILE
# Out:
# 'Data/results_in_progress_STL_pizza.json'

# %%
## Specify folder for saving data
FOLDER = 'Data/'
os.makedirs(FOLDER,exist_ok=True)

location.split(',')[0]

# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)
## If it does not exist: 
if file_exists ==False:
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder,exist_ok=True)
        
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE, 'w')as f:
        json.dump([],f)
        
## If it exists, inform user
else:
        print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/results_in_progress_STL_pizza.json already exists.

# %%
# use our yelp_api variable's search_query method to perform our API call
results = yelp.search_query(term=term,location=location)

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['businesses']
# Out:
# [{'id': 'P2XJbQZmf1zvWp9L_THdjQ',
#   'alias': 'sauce-on-the-side-saint-louis-2',
#   'name': 'Sauce on the Side',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/W5pcDM5w4srtEnXZ1ilFfQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sauce-on-the-side-saint-louis-2?adjust_creative=2VVn9tAdE7T7A_bSyPHVAg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2VVn9tAdE7T7A_bSyPHVAg',
#   'review_count': 578,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 38.629780709389, 'longitude': -90.1920634267984},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '411 N 8th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Saint Louis',
#    'zip_code': '63101',
#    'country': 'US',
#    'state': 'MO',
#    'display_address': ['411 N 8th St', 'Saint Louis, MO 63101']},
#   'phone': '+13142415667',
#   'display_phone': '(314) 241-5667',
#   'distance': 349.5669201672009},
#  {'id': 'h_iXktY-bFKv6KR_G6yACA',
#   'alias': 'the-sliced-pint-st-louis',
#   'name': 'The Sliced Pint',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/x6XMAB5dMaEPu7ejQW3jUg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-sliced-pint-st-louis?adjust_creative=2VVn9tAdE7T7A_bSyPHVAg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2VVn9tAdE7T7A_bSyPHVAg',
#   'review_count': 218,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 38.632440054777, 'longitude': -90.2004899999933},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1511 Washington Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'St Louis',
#    'zip_code': '63103',
#    'country': 'US',
#    'state': 'MO',
#    'display_address': ['1511 Washington Ave', 'St Louis, MO 63103']},
#   'phone': '+13146968787',
#   'display_phone': '(314) 696-8787',
#   'distance': 686.8569485667344},
#  {'id': 'ZoV8kXQopyz24dJBlFByRA',
#   'alias': 'imos-pizza-saint-louis-51',
#   'name': "Imo's Pizza",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/E0JcHdKy4B9Qekzjs9Knjw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/imos-pizza-saint-louis-51?adjust_creative=2VVn9tAdE7T7A_bSyPHVAg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2VVn9tAdE7T7A_bSyPHVAg',
#   'review_count': 12,
#   'categories': [{'alias': 'fooddeliveryservices',
#     'title': 'Food Delivery Services'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 38.63511817445793,
#    'longitude': -90.20218985495582},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '800 N 17th St',
#    'address2': None,
#    'address3': None,
#    'city': 'Saint Louis',
#    'zip_code': '63106',
#    'country': 'US',
#    'state': 'MO',
#    'display_address': ['800 N 17th St', 'Saint Louis, MO 63106']},
#   'phone': '+18774081890',
#   'display_phone': '(877) 408-1890',
#   'distance': 868.5129126351301},
#  {'id': 'GeLwhGlX8XsIsH-o3Wdc5w',
#   'alias': '360-st-louis-saint-louis',
#   'name': '360 St. Louis',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1C8MVOq2v-YYgoc5UFmv9w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/360-st-louis-saint-louis?adjust_creative=2VVn9tAdE7T7A_bSyPHVAg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2VVn9tAdE7T7A_bSyPHVAg',
#   'review_count': 809,
#   'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#    {'alias': 'tapas', 'title': 'Tapas Bars'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 38.62518, 'longitude': -90.19104},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1 S Broadway',
#    'address2': '',
#    'address3': '',
#    'city': 'Saint Louis',
#    'zip_code': '63102',
#    'country': 'US',
#    'state': 'MO',
#    'display_address': ['1 S Broadway', 'Saint Louis, MO 63102']},
#   'phone': '+13142418439',
#   'display_phone': '(314) 241-8439',
#   'distance': 845.5075773914164},
#  {'id': '4AUdcIJ8BoEve-GUm9SCEg',
#   'alias': 'samwiches-saint-louis',
#   'name': 'Samwiches',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wvUYxDCZ8Acgtj-GrsHDuQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/samwiches-saint-louis?adjust_creative=2VVn9tAdE7T7A_bSyPHVAg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2VVn9tAdE7T7A_bSyPHVAg',
#   'review_count': 14,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 38.63357, 'longitude': -90.20043},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '701 N 15th St',
#    'address2': '',
#    'address3': None,
#    'city': 'Saint Louis',
#    'zip_code': '63103',
#    'country': 'US',
#    'state': 'MO',
#    'display_address': ['701 N 15th St', 'Saint Louis, MO 63103']},
#   'phone': '+13146214133',
#   'display_phone': '(314) 621-4133',
#   'distance': 695.2183199473628},
#  {'id': 'FcpUVh4rkOdQ22raeVPekg',
#   'alias': 'papa-johns-pizza-st-louis-8',
#   'name': 'Papa Johns Pizza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BidfJfoNYYUnYL7grxd2Bw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/papa-johns-pizza-st-louis-8?adjust_creative=2VVn9tAdE7T7A_bSyPHVAg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2VVn9tAdE7T7A_bSyPHVAg',
#   'review_count': 81,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#   'rating': 1.5,
#   'coordinates': {'latitude': 38.6291607, 'longitude': -90.1979467},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '201 N Tucker',
#    'address2': 'Ste E',
#    'address3': '',
#    'city': 'St. Louis',
#    'zip_code': '63103',
#    'country': 'US',
#    'state': 'MO',
#    'display_address': ['201 N Tucker', 'Ste E', 'St. Louis, MO 63103']},
#   'phone': '+13146217272',
#   'display_phone': '(314) 621-7272',
#   'distance': 622.7978493973854},
#  {'id': 'vjFUl6yKiJecvGS0wlUuuQ',
#   'alias': 'the-lou-eats-and-drinks-st-louis',
#   'name': 'The Lou Eats & Drinks',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pOxkdoCTWsrKl-1qXQ3-Lw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-lou-eats-and-drinks-st-louis?adjust_creative=2VVn9tAdE7T7A_bSyPHVAg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2VVn9tAdE7T7A_bSyPHVAg',
#   'review_count': 64,
#   'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 38.63028, 'longitude': -90.18417},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '710 N 2nd St',
#    'address2': None,
#    'address3': '',
#    'city': 'St. Louis',
#    'zip_code': '63102',
#    'country': 'US',
#    'state': 'MO',
#    'display_address': ['710 N 2nd St', 'St. Louis, MO 63102']},
#   'phone': '+13146219570',
#   'display_phone': '(314) 621-9570',
#   'distance': 773.275397151804},
#  {'id': 'Hgbr9NN7w8MKXbxbI3Bnew',
#   'alias': 'imos-pizza-saint-louis-37',
#   'name': "Imo's Pizza",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bZMH-kPOcG9JwhKwGSpoRw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/imos-pizza-saint-louis-37?adjust_creative=2VVn9tAdE7T7A_bSyPHVAg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2VVn9tAdE7T7A_bSyPHVAg',
#   'review_count': 96,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 38.63481340762346,
#    'longitude': -90.20290248419691},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1701 Delmar Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Saint Louis',
#    'zip_code': '63103',
#    'country': 'US',
#    'state': 'MO',
#    'display_address': ['1701 Delmar Blvd', 'Saint Louis, MO 63103']},
#   'phone': '+13142416000',
#   'display_phone': '(314) 241-6000',
#   'distance': 919.5796419659819},
#  {'id': 'iiBCWBFwb_bzlH9usC5XPQ',
#   'alias': 'the-over-under-bar-and-grill-saint-louis-2',
#   'name': 'The Over/Under Bar & Grill',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GwOPIo243dhXMEo3RDVFbQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-over-under-bar-and-grill-saint-louis-2?adjust_creative=2VVn9tAdE7T7A_bSyPHVAg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2VVn9tAdE7T7A_bSyPHVAg',
#   'review_count': 326,
#   'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 38.6312038404206,
#    'longitude': -90.1933467542439},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '911 Washington Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Saint Louis',
#    'zip_code': '63101',
#    'country': 'US',
#    'state': 'MO',
#    'display_address': ['911 Washington Ave', 'Saint Louis, MO 63101']},
#   'phone': '+13146218881',
#   'display_phone': '(314) 621-8881',
#   'distance': 198.9055735062468},
#  {'id': 'IFKCqDKdrAOtph_TEi8ycw',
#   'alias': 'jack-patricks-bar-and-grill-saint-louis',
#   'name': "Jack Patrick's Bar & Grill",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bazjg_oAYcHm5SwQixBeSw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jack-patricks-bar-and-grill-saint-louis?adjust_creative=2VVn9tAdE7T7A_bSyPHVAg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2VVn9tAdE7T7A_bSyPHVAg',
#   'review_count': 117,
#   'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#    {'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 38.62896, 'longitude': -90.19487},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '1000 Olive St',
#    'address2': '',
#    'address3': '',
#    'city': 'Saint Louis',
#    'zip_code': '63101',
#    'country': 'US',
#    'state': 'MO',
#    'display_address': ['1000 Olive St', 'Saint Louis, MO 63101']},
#   'phone': '+13144368879',
#   'display_phone': '(314) 436-8879',
#   'distance': 474.0221004659198},
#  {'id': '6t0sNev22mcbvOB4gYVVOw',
#   'alias': 'pw-pizza-saint-louis-2',
#   'name': 'PW Pizza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zxt-ELG7dFdAn-wsvAgIag/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pw-pizza-saint-louis-2?adjust_creative=2VVn9tAdE7T7A_bSyPHVAg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2VVn9tAdE7T7A_bSyPHVAg',
#   'review_count': 338,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'desserts', 'title': 'Desserts'},
#    {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 38.62134, 'longitude': -90.212956},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '2017 Chouteau Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Saint Louis',
#    'zip_code': '63103',
#    'country': 'US',
#    'state': 'MO',
#    'display_address': ['2017 Chouteau Ave', 'Saint Louis, MO 63103']},
#   'phone': '+13142417799',
#   'display_phone': '(314) 241-7799',
#   'distance': 2185.571003140032},
#  {'id': 'DRCCplzDIE3iCcSVdOdczw',
#   'alias': 'pop-s-kitchen-st-louis',
#   'name': 'Pop’s Kitchen',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oQbtLKF0lZF7jApQkHYalg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pop-s-kitchen-st-louis?adjust_creative=2VVn9tAdE7T7A_bSyPHVAg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2VVn9tAdE7T7A_bSyPHVAg',
#   'review_count': 19,
#   'categories': [{'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#    {'alias': 'fishnchips', 'title': 'Fish & Chips'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 38.632029014492254,
#    'longitude': -90.19955007055259},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '1330 Washington Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'St. Louis',
#    'zip_code': '63103',
#    'country': 'US',
#    'state': 'MO',
#    'display_address': ['1330 Washington Ave', 'St. Louis, MO 63103']},
#   'phone': '+13142820920',
#   'display_phone': '(314) 282-0920',
#   'distance': 610.9942648732936},
#  {'id': 'rQ0g1hm_BKsIcRfbHbyPrg',
#   'alias': 'ultima-cucina-st-louis',
#   'name': 'Ultima Cucina',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WWusIy7qaPjPVz3EtrOdpQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ultima-cucina-st-louis?adjust_creative=2VVn9tAdE7T7A_bSyPHVAg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2VVn9tAdE7T7A_bSyPHVAg',
#   'review_count': 54,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 38.63267, 'longitude': -90.200566},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1501 Washington Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'St Louis',
#    'zip_code': '63103',
#    'country': 'US',
#    'state': 'MO',
#    'display_address': ['1501 Washington Ave', 'St Louis, MO 63103']},
#   'phone': '+13143902500',
#   'display_phone': '(314) 390-2500',
#   'distance': 692.0402999173248},
#  {'id': 'PI0aGMmM33x1QF69JUsaUw',
#   'alias': 'the-train-shed-st-louis-2',
#   'name': 'The Train Shed',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xUrMFIZXocoUTzuROH7qVg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-train-shed-st-louis-2?adjust_creative=2VVn9tAdE7T7A_bSyPHVAg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2VVn9tAdE7T7A_bSyPHVAg',
#   'review_count': 233,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 38.6277735, 'longitude': -90.20799219999999},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '201 S 18th St',
#    'address2': '',
#    'address3': None,
#    'city': 'St Louis',
#    'zip_code': '63103',
#    'country': 'US',
#    'state': 'MO',
#    'display_address': ['201 S 18th St', 'St Louis, MO 63103']},
#   'phone': '+13149233949',
#   'display_phone': '(314) 923-3949',
#   'distance': 1452.9773879653164},
#  {'id': 'VrRmLUUT7RkJnRmtoycivg',
#   'alias': 'the-slice-pizzeria-st-louis',
#   'name': 'The Slice Pizzeria',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hZTmyGvEMoSZ9-uzOtwUEA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-slice-pizzeria-st-louis?adjust_creative=2VVn9tAdE7T7A_bSyPHVAg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2VVn9tAdE7T7A_bSyPHVAg',
#   'review_count': 1,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 1.0,
#   'coordinates': {'latitude': 38.632684555646634,
#    'longitude': -90.18476951376137},
#   'transactions': [],
#   'location': {'address1': '999 N 2nd St',
#    'address2': '',
#    'address3': None,
#    'city': 'St. Louis',
#    'zip_code': '63102',
#    'country': 'US',
#    'state': 'MO',
#    'display_address': ['999 N 2nd St', 'St. Louis, MO 63102']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 680.9251210332246},
#  {'id': 'CIZiGL2t5x-WcmWMyzuKaA',
#   'alias': 'imos-pizza-saint-louis-8',
#   'name': "Imo's Pizza",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qE0o5fXERCdTLpDmv4jFPA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/imos-pizza-saint-louis-8?adjust_creative=2VVn9tAdE7T7A_bSyPHVAg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2VVn9tAdE7T7A_bSyPHVAg',
#   'review_count': 93,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 2.0,
#   'coordinates': {'latitude': 38.61743, 'longitude': -90.19233},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '904 S 4th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Saint Louis',
#    'zip_code': '63102',
#    'country': 'US',
#    'state': 'MO',
#    'display_address': ['904 S 4th St', 'Saint Louis, MO 63102']},
#   'phone': '+13144214667',
#   'display_phone': '(314) 421-4667',
#   'distance': 1713.3993134604577},
#  {'id': 'bDwAOwlB-HkOqvSfHumfng',
#   'alias': 'pharaoh-s-donuts-saint-louis',
#   'name': 'Pharaoh’s Donuts',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nS0nzgfddo0uKNUr8B-mxw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pharaoh-s-donuts-saint-louis?adjust_creative=2VVn9tAdE7T7A_bSyPHVAg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2VVn9tAdE7T7A_bSyPHVAg',
#   'review_count': 346,
#   'categories': [{'alias': 'donuts', 'title': 'Donuts'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 38.628186, 'longitude': -90.193652},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '202 N 9th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Saint Louis',
#    'zip_code': '63101',
#    'country': 'US',
#    'state': 'MO',
#    'display_address': ['202 N 9th St', 'Saint Louis, MO 63101']},
#   'phone': '+13143510285',
#   'display_phone': '(314) 351-0285',
#   'distance': 531.5734076892068},
#  {'id': 'kBCB53psaoKcHwv4kNByOg',
#   'alias': 'lombardos-trattoria-saint-louis-2',
#   'name': "Lombardo's Trattoria",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6F8yj4n2Ug02Wg0SrUHAew/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lombardos-trattoria-saint-louis-2?adjust_creative=2VVn9tAdE7T7A_bSyPHVAg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2VVn9tAdE7T7A_bSyPHVAg',
#   'review_count': 388,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 38.6279912, 'longitude': -90.2102467},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '201 S 20th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Saint Louis',
#    'zip_code': '63103',
#    'country': 'US',
#    'state': 'MO',
#    'display_address': ['201 S 20th St', 'Saint Louis, MO 63103']},
#   'phone': '+13146210666',
#   'display_phone': '(314) 621-0666',
#   'distance': 1626.66405718874},
#  {'id': '2VO-zlWWuqwP_8WPbEDWgA',
#   'alias': 'insomnia-cookie-st-louis',
#   'name': 'Insomnia Cookie',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/J4PQC21hGhGIRFDfV1xAQg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/insomnia-cookie-st-louis?adjust_creative=2VVn9tAdE7T7A_bSyPHVAg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2VVn9tAdE7T7A_bSyPHVAg',
#   'review_count': 101,
#   'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#    {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#    {'alias': 'fooddeliveryservices', 'title': 'Food Delivery Services'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 38.6315344405067, 'longitude': -90.196327896399},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '1136 Washington Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'St. Louis',
#    'zip_code': '63101',
#    'country': 'US',
#    'state': 'MO',
#    'display_address': ['1136 Washington Ave', 'St. Louis, MO 63101']},
#   'phone': '+13146904022',
#   'display_phone': '(314) 690-4022',
#   'distance': 357.1353259232766},
#  {'id': 'PX3xJq76hHYTLZHf_htdxQ',
#   'alias': 'quattro-trattoria-pizzeria-saint-louis-2',
#   'name': 'Quattro Trattoria + Pizzeria',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vqCyX9y7827VQV28hglrzg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/quattro-trattoria-pizzeria-saint-louis-2?adjust_creative=2VVn9tAdE7T7A_bSyPHVAg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2VVn9tAdE7T7A_bSyPHVAg',
#   'review_count': 17,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 38.62371, 'longitude': -90.19503},
#   'transactions': ['delivery'],
#   'location': {'address1': '811 Spruce St',
#    'address2': '',
#    'address3': None,
#    'city': 'Saint Louis',
#    'zip_code': '63102',
#    'country': 'US',
#    'state': 'MO',
#    'display_address': ['811 Spruce St', 'Saint Louis, MO 63102']},
#   'phone': '+13145525850',
#   'display_phone': '(314) 552-5850',
#   'distance': 1016.2311594494664}]

# %%
results['total']
# Out:
# 60

# %%
pd.DataFrame(results['businesses'])
# Out:
#                         id                                       alias  \
# 0   P2XJbQZmf1zvWp9L_THdjQ             sauce-on-the-side-saint-louis-2
# 1   h_iXktY-bFKv6KR_G6yACA                    the-sliced-pint-st-louis
# 2   ZoV8kXQopyz24dJBlFByRA                   imos-pizza-saint-louis-51
# 3   GeLwhGlX8XsIsH-o3Wdc5w                    360-st-louis-saint-louis
# 4   4AUdcIJ8BoEve-GUm9SCEg                       samwiches-saint-louis
# 5   FcpUVh4rkOdQ22raeVPekg                 papa-johns-pizza-st-louis-8
# 6   vjFUl6yKiJecvGS0wlUuuQ            the-lou-eats-and-drinks-st-louis
# 7   Hgbr9NN7w8MKXbxbI3Bnew                   imos-pizza-saint-louis-37
# 8   iiBCWBFwb_bzlH9usC5XPQ  the-over-under-bar-and-grill-saint-louis-2
# 9   IFKCqDKdrAOtph_TEi8ycw     jack-patricks-bar-and-grill-saint-louis
# 10  6t0sNev22mcbvOB4gYVVOw                      pw-pizza-saint-louis-2
# 11  DRCCplzDIE3iCcSVdOdczw                      pop-s-kitchen-st-louis
# 12  rQ0g1hm_BKsIcRfbHbyPrg                      ultima-cucina-st-louis
# 13  PI0aGMmM33x1QF69JUsaUw                   the-train-shed-st-louis-2
# 14  VrRmLUUT7RkJnRmtoycivg                 the-slice-pizzeria-st-louis
# 15  CIZiGL2t5x-WcmWMyzuKaA                    imos-pizza-saint-louis-8
# 16  bDwAOwlB-HkOqvSfHumfng                pharaoh-s-donuts-saint-louis
# 17  kBCB53psaoKcHwv4kNByOg           lombardos-trattoria-saint-louis-2
# 18  2VO-zlWWuqwP_8WPbEDWgA                    insomnia-cookie-st-louis
# 19  PX3xJq76hHYTLZHf_htdxQ    quattro-trattoria-pizzeria-saint-louis-2
#
#                             name  \
# 0              Sauce on the Side
# 1                The Sliced Pint
# 2                    Imo's Pizza
# 3                  360 St. Louis
# 4                      Samwiches
# 5               Papa Johns Pizza
# 6          The Lou Eats & Drinks
# 7                    Imo's Pizza
# 8     The Over/Under Bar & Grill
# 9     Jack Patrick's Bar & Grill
# 10                      PW Pizza
# 11                 Pop’s Kitchen
# 12                 Ultima Cucina
# 13                The Train Shed
# 14            The Slice Pizzeria
# 15                   Imo's Pizza
# 16              Pharaoh’s Donuts
# 17          Lombardo's Trattoria
# 18               Insomnia Cookie
# 19  Quattro Trattoria + Pizzeria
#
#                                             image_url  is_closed  \
# 0   https://s3-media4.fl.yelpcdn.com/bphoto/W5pcDM...      False
# 1   https://s3-media4.fl.yelpcdn.com/bphoto/x6XMAB...      False
# 2   https://s3-media3.fl.yelpcdn.com/bphoto/E0JcHd...      False
# 3   https://s3-media4.fl.yelpcdn.com/bphoto/1C8MVO...      False
# 4   https://s3-media1.fl.yelpcdn.com/bphoto/wvUYxD...      False
# 5   https://s3-media2.fl.yelpcdn.com/bphoto/BidfJf...      False
# 6   https://s3-media2.fl.yelpcdn.com/bphoto/pOxkdo...      False
# 7   https://s3-media2.fl.yelpcdn.com/bphoto/bZMH-k...      False
# 8   https://s3-media2.fl.yelpcdn.com/bphoto/GwOPIo...      False
# 9   https://s3-media2.fl.yelpcdn.com/bphoto/bazjg_...      False
# 10  https://s3-media2.fl.yelpcdn.com/bphoto/zxt-EL...      False
# 11  https://s3-media3.fl.yelpcdn.com/bphoto/oQbtLK...      False
# 12  https://s3-media2.fl.yelpcdn.com/bphoto/WWusIy...      False
# 13  https://s3-media4.fl.yelpcdn.com/bphoto/xUrMFI...      False
# 14  https://s3-media3.fl.yelpcdn.com/bphoto/hZTmyG...      False
# 15  https://s3-media3.fl.yelpcdn.com/bphoto/qE0o5f...      False
# 16  https://s3-media2.fl.yelpcdn.com/bphoto/nS0nzg...      False
# 17  https://s3-media2.fl.yelpcdn.com/bphoto/6F8yj4...      False
# 18  https://s3-media2.fl.yelpcdn.com/bphoto/J4PQC2...      False
# 19  https://s3-media3.fl.yelpcdn.com/bphoto/vqCyX9...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/sauce-on-the-side-sai...           578
# 1   https://www.yelp.com/biz/the-sliced-pint-st-lo...           218
# 2   https://www.yelp.com/biz/imos-pizza-saint-loui...            12
# 3   https://www.yelp.com/biz/360-st-louis-saint-lo...           809
# 4   https://www.yelp.com/biz/samwiches-saint-louis...            14
# 5   https://www.yelp.com/biz/papa-johns-pizza-st-l...            81
# 6   https://www.yelp.com/biz/the-lou-eats-and-drin...            64
# 7   https://www.yelp.com/biz/imos-pizza-saint-loui...            96
# 8   https://www.yelp.com/biz/the-over-under-bar-an...           326
# 9   https://www.yelp.com/biz/jack-patricks-bar-and...           117
# 10  https://www.yelp.com/biz/pw-pizza-saint-louis-...           338
# 11  https://www.yelp.com/biz/pop-s-kitchen-st-loui...            19
# 12  https://www.yelp.com/biz/ultima-cucina-st-loui...            54
# 13  https://www.yelp.com/biz/the-train-shed-st-lou...           233
# 14  https://www.yelp.com/biz/the-slice-pizzeria-st...             1
# 15  https://www.yelp.com/biz/imos-pizza-saint-loui...            93
# 16  https://www.yelp.com/biz/pharaoh-s-donuts-sain...           346
# 17  https://www.yelp.com/biz/lombardos-trattoria-s...           388
# 18  https://www.yelp.com/biz/insomnia-cookie-st-lo...           101
# 19  https://www.yelp.com/biz/quattro-trattoria-piz...            17
#
#                                            categories  rating  \
# 0   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 1   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     3.5
# 2   [{'alias': 'fooddeliveryservices', 'title': 'F...     2.5
# 3   [{'alias': 'lounges', 'title': 'Lounges'}, {'a...     4.0
# 4              [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 5   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     1.5
# 6   [{'alias': 'cocktailbars', 'title': 'Cocktail ...     3.5
# 7              [{'alias': 'pizza', 'title': 'Pizza'}]     3.0
# 8   [{'alias': 'sportsbars', 'title': 'Sports Bars...     3.5
# 9   [{'alias': 'sportsbars', 'title': 'Sports Bars...     4.0
# 10  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 11  [{'alias': 'chicken_wings', 'title': 'Chicken ...     4.0
# 12  [{'alias': 'steak', 'title': 'Steakhouses'}, {...     4.0
# 13  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     3.5
# 14             [{'alias': 'pizza', 'title': 'Pizza'}]     1.0
# 15  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     2.0
# 16           [{'alias': 'donuts', 'title': 'Donuts'}]     4.5
# 17  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.0
# 18  [{'alias': 'desserts', 'title': 'Desserts'}, {...     3.5
# 19         [{'alias': 'italian', 'title': 'Italian'}]     3.0
#
#                                           coordinates        transactions  \
# 0   {'latitude': 38.629780709389, 'longitude': -90...  [pickup, delivery]
# 1   {'latitude': 38.632440054777, 'longitude': -90...  [delivery, pickup]
# 2   {'latitude': 38.63511817445793, 'longitude': -...          [delivery]
# 3      {'latitude': 38.62518, 'longitude': -90.19104}                  []
# 4      {'latitude': 38.63357, 'longitude': -90.20043}          [delivery]
# 5   {'latitude': 38.6291607, 'longitude': -90.1979...  [pickup, delivery]
# 6      {'latitude': 38.63028, 'longitude': -90.18417}  [pickup, delivery]
# 7   {'latitude': 38.63481340762346, 'longitude': -...          [delivery]
# 8   {'latitude': 38.6312038404206, 'longitude': -9...  [pickup, delivery]
# 9      {'latitude': 38.62896, 'longitude': -90.19487}          [delivery]
# 10    {'latitude': 38.62134, 'longitude': -90.212956}          [delivery]
# 11  {'latitude': 38.632029014492254, 'longitude': ...  [pickup, delivery]
# 12    {'latitude': 38.63267, 'longitude': -90.200566}  [pickup, delivery]
# 13  {'latitude': 38.6277735, 'longitude': -90.2079...          [delivery]
# 14  {'latitude': 38.632684555646634, 'longitude': ...                  []
# 15     {'latitude': 38.61743, 'longitude': -90.19233}          [delivery]
# 16   {'latitude': 38.628186, 'longitude': -90.193652}  [pickup, delivery]
# 17  {'latitude': 38.6279912, 'longitude': -90.2102...  [pickup, delivery]
# 18  {'latitude': 38.6315344405067, 'longitude': -9...  [pickup, delivery]
# 19     {'latitude': 38.62371, 'longitude': -90.19503}          [delivery]
#
#    price                                           location         phone  \
# 0     $$  {'address1': '411 N 8th St', 'address2': '', '...  +13142415667
# 1     $$  {'address1': '1511 Washington Ave', 'address2'...  +13146968787
# 2      $  {'address1': '800 N 17th St', 'address2': None...  +18774081890
# 3     $$  {'address1': '1 S Broadway', 'address2': '', '...  +13142418439
# 4     $$  {'address1': '701 N 15th St', 'address2': '', ...  +13146214133
# 5      $  {'address1': '201 N Tucker', 'address2': 'Ste ...  +13146217272
# 6     $$  {'address1': '710 N 2nd St', 'address2': None,...  +13146219570
# 7     $$  {'address1': '1701 Delmar Blvd', 'address2': '...  +13142416000
# 8     $$  {'address1': '911 Washington Ave', 'address2':...  +13146218881
# 9      $  {'address1': '1000 Olive St', 'address2': '', ...  +13144368879
# 10    $$  {'address1': '2017 Chouteau Ave', 'address2': ...  +13142417799
# 11   NaN  {'address1': '1330 Washington Ave', 'address2'...  +13142820920
# 12    $$  {'address1': '1501 Washington Ave', 'address2'...  +13143902500
# 13    $$  {'address1': '201 S 18th St', 'address2': '', ...  +13149233949
# 14   NaN  {'address1': '999 N 2nd St', 'address2': '', '...
# 15     $  {'address1': '904 S 4th St', 'address2': '', '...  +13144214667
# 16     $  {'address1': '202 N 9th St', 'address2': '', '...  +13143510285
# 17    $$  {'address1': '201 S 20th St', 'address2': '', ...  +13146210666
# 18     $  {'address1': '1136 Washington Ave', 'address2'...  +13146904022
# 19   NaN  {'address1': '811 Spruce St', 'address2': '', ...  +13145525850
#
#      display_phone     distance
# 0   (314) 241-5667   349.566920
# 1   (314) 696-8787   686.856949
# 2   (877) 408-1890   868.512913
# 3   (314) 241-8439   845.507577
# 4   (314) 621-4133   695.218320
# 5   (314) 621-7272   622.797849
# 6   (314) 621-9570   773.275397
# 7   (314) 241-6000   919.579642
# 8   (314) 621-8881   198.905574
# 9   (314) 436-8879   474.022100
# 10  (314) 241-7799  2185.571003
# 11  (314) 282-0920   610.994265
# 12  (314) 390-2500   692.040300
# 13  (314) 923-3949  1452.977388
# 14                   680.925121
# 15  (314) 421-4667  1713.399313
# 16  (314) 351-0285   531.573408
# 17  (314) 621-0666  1626.664057
# 18  (314) 690-4022   357.135326
# 19  (314) 552-5850  1016.231159

# %%
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %%
# Use math.ceil to round up for the total number of pages of results.
import time, math
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 3

# %%
for i in tqdm_notebook( range(1,n_pages+1)):
    
    ## Read in results in progress file and check the length
    with open(JSON_FILE, 'r') as f:
        previous_results = json.load(f)
    ## save number of results for to use as offset
    n_results = len(previous_results)
    
    if (n_results + results_per_page) > 1000:
        print('Exceeded 1000 api calls. Stopping loop.')
        break
    
    ## use n_results as the OFFSET 
    results = yelp.search_query(location=location,
                                    term=term, 
                                    offset=n_results)
    
    
    
    ## append new results and save to file
    previous_results.extend(results['businesses'])
    
    # display(previous_results)
    with open(JSON_FILE,'w') as f:
        json.dump(previous_results,f)
    
    time.sleep(.2)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
# load final results
final_df = pd.read_json(JSON_FILE)
display(final_df.head(), final_df.tail())
# Out:
#                        id                            alias               name  \
# 0  P2XJbQZmf1zvWp9L_THdjQ  sauce-on-the-side-saint-louis-2  Sauce on the Side
# 1  h_iXktY-bFKv6KR_G6yACA         the-sliced-pint-st-louis    The Sliced Pint
# 2  ZoV8kXQopyz24dJBlFByRA        imos-pizza-saint-louis-51        Imo's Pizza
# 3  GeLwhGlX8XsIsH-o3Wdc5w         360-st-louis-saint-louis      360 St. Louis
# 4  4AUdcIJ8BoEve-GUm9SCEg            samwiches-saint-louis          Samwiches
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/W5pcDM...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/x6XMAB...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/E0JcHd...      False
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/1C8MVO...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/wvUYxD...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/sauce-on-the-side-sai...           578
# 1  https://www.yelp.com/biz/the-sliced-pint-st-lo...           218
# 2  https://www.yelp.com/biz/imos-pizza-saint-loui...            12
# 3  https://www.yelp.com/biz/360-st-louis-saint-lo...           809
# 4  https://www.yelp.com/biz/samwiches-saint-louis...            14
#
#                                           categories  rating  \
# 0  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 1  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     3.5
# 2  [{'alias': 'fooddeliveryservices', 'title': 'F...     2.5
# 3  [{'alias': 'lounges', 'title': 'Lounges'}, {'a...     4.0
# 4             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
#
#                                          coordinates        transactions  \
# 0  {'latitude': 38.629780709389, 'longitude': -90...  [delivery, pickup]
# 1  {'latitude': 38.632440054777, 'longitude': -90...  [delivery, pickup]
# 2  {'latitude': 38.63511817445793, 'longitude': -...          [delivery]
# 3     {'latitude': 38.62518, 'longitude': -90.19104}                  []
# 4     {'latitude': 38.63357, 'longitude': -90.20043}          [delivery]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '411 N 8th St', 'address2': '', '...  +13142415667
# 1    $$  {'address1': '1511 Washington Ave', 'address2'...  +13146968787
# 2     $  {'address1': '800 N 17th St', 'address2': None...  +18774081890
# 3    $$  {'address1': '1 S Broadway', 'address2': '', '...  +13142418439
# 4    $$  {'address1': '701 N 15th St', 'address2': '', ...  +13146214133
#
#     display_phone    distance
# 0  (314) 241-5667  349.566920
# 1  (314) 696-8787  686.856949
# 2  (877) 408-1890  868.512913
# 3  (314) 241-8439  845.507577
# 4  (314) 621-4133  695.218320
#                         id                                   alias  \
# 55  4z-7YMw9_YMszg2oETuKbw                      subway-st-louis-26
# 56  F0Q9o6yuYh8f0DYl1RFjxQ  sqwires-restaurant-and-market-st-louis
# 57  Xsb03EMofMgLioiRLtU19Q            old-rock-house-saint-louis-2
# 58  iIU4GS5d-TKYbDGbUzmxEA                taco-bell-saint-louis-23
# 59  u4WC_qHGn03jwNdVmW5vaQ       baileys-chocolate-bar-saint-louis
#
#                            name  \
# 55                       Subway
# 56  SqWires Restaurant & Market
# 57               Old Rock House
# 58                    Taco Bell
# 59       Baileys' Chocolate Bar
#
#                                             image_url  is_closed  \
# 55  https://s3-media2.fl.yelpcdn.com/bphoto/zOp_bK...      False
# 56  https://s3-media4.fl.yelpcdn.com/bphoto/iVtqFw...      False
# 57  https://s3-media3.fl.yelpcdn.com/bphoto/ohHsCQ...      False
# 58  https://s3-media3.fl.yelpcdn.com/bphoto/5RNO8m...      False
# 59  https://s3-media4.fl.yelpcdn.com/bphoto/zMekLj...      False
#
#                                                   url  review_count  \
# 55  https://www.yelp.com/biz/subway-st-louis-26?ad...            11
# 56  https://www.yelp.com/biz/sqwires-restaurant-an...           464
# 57  https://www.yelp.com/biz/old-rock-house-saint-...            91
# 58  https://www.yelp.com/biz/taco-bell-saint-louis...            56
# 59  https://www.yelp.com/biz/baileys-chocolate-bar...           609
#
#                                            categories  rating  \
# 55   [{'alias': 'sandwiches', 'title': 'Sandwiches'}]     2.0
# 56  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.0
# 57  [{'alias': 'newamerican', 'title': 'American (...     3.5
# 58  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     1.5
# 59  [{'alias': 'lounges', 'title': 'Lounges'}, {'a...     4.0
#
#                                          coordinates transactions price  \
# 55  {'latitude': 38.626536, 'longitude': -90.196698}   [delivery]     $
# 56   {'latitude': 38.6161, 'longitude': -90.2116999}     [pickup]    $$
# 57    {'latitude': 38.61526, 'longitude': -90.19626}           []    $$
# 58  {'latitude': 38.617239, 'longitude': -90.193209}   [delivery]     $
# 59  {'latitude': 38.617555, 'longitude': -90.212731}   [delivery]    $$
#
#                                              location         phone  \
# 55  {'address1': '1010 Market St', 'address2': 'St...  +13145881411
# 56  {'address1': '1415 S 18th St', 'address2': '',...  +13148653522
# 57  {'address1': '1200 S 7th St', 'address2': '', ...  +13145880505
# 58  {'address1': '501 Chouteau', 'address2': None,...  +13142410223
# 59  {'address1': '1915 Park Ave', 'address2': '', ...  +13142418100
#
#      display_phone     distance
# 55  (314) 588-1411   791.572652
# 56  (314) 865-3522  2489.446938
# 57  (314) 588-0505  1988.454957
# 58  (314) 241-0223  1741.763964
# 59  (314) 241-8100  2456.212467

# %%
final_df.duplicated(subset='id').sum()
# Out:
# 0

# %%
final_df.to_csv('Data/final_results_STL_pizza.csv.gz', compression='gzip',index=False)
